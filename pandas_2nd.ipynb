# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Mohan shyam\Downloads\trips_data.csv")

# %%
df.head()
# Out:
#    City Product Type Trip or Order Status                   Request Time  \
# 0   458        Black            COMPLETED  2021-01-13 22:06:46 +0000 UTC
# 1   458          VIP            COMPLETED  2021-01-13 20:21:05 +0000 UTC
# 2   458          VIP            COMPLETED  2021-01-03 00:23:22 +0000 UTC
# 3   458          VIP            COMPLETED  2020-12-11 23:16:33 +0000 UTC
# 4   458          VIP            COMPLETED  2020-12-11 00:35:46 +0000 UTC
#
#                  Begin Trip Time  Begin Trip Lat  Begin Trip Lng  \
# 0  2021-01-13 22:11:10 +0000 UTC      -23.599752      -46.715954
# 1  2021-01-13 20:27:29 +0000 UTC      -23.559298      -46.666454
# 2  2021-01-03 00:33:00 +0000 UTC      -23.626593      -46.659410
# 3  2020-12-11 23:27:32 +0000 UTC      -23.559410      -46.666435
# 4  2020-12-11 00:46:46 +0000 UTC      -23.584846      -46.663590
#
#                     Dropoff Time  Dropoff Lat  Dropoff Lng  Distance (miles)  \
# ...

# %%
df.shape
# Out:
# (554, 13)

# %%
df.sample()
# Out:
#      City Product Type Trip or Order Status                   Request Time  \
# 132   458        UberX            COMPLETED  2019-07-03 11:35:33 +0000 UTC
#
#                    Begin Trip Time  Begin Trip Lat  Begin Trip Lng  \
# 132  2019-07-03 11:38:28 +0000 UTC       -23.58968       -46.63409
#
#                       Dropoff Time  Dropoff Lat  Dropoff Lng  \
# 132  2019-07-03 12:04:08 +0000 UTC    -23.61135    -46.57091
#
#      Distance (miles)  Fare Amount Fare Currency
# 132              5.53        19.64           BRL

# %%
df.tail()
# Out:
#      City Product Type Trip or Order Status                   Request Time  \
# 549   458         POOL            COMPLETED  2016-06-22 11:07:02 +0000 UTC
# 550   458        uberX            COMPLETED  2016-04-07 00:30:46 +0000 UTC
# 551   458        uberX            COMPLETED  2016-04-06 21:16:52 +0000 UTC
# 552   458        uberX             CANCELED  2016-04-06 21:12:03 +0000 UTC
# 553   458        uberX             CANCELED  2015-12-17 23:52:50 +0000 UTC
#
#                    Begin Trip Time  Begin Trip Lat  Begin Trip Lng  \
# 549  2016-06-22 11:14:17 +0000 UTC      -23.616073      -46.665949
# 550  2016-04-07 00:35:23 +0000 UTC      -23.569478      -46.672408
# 551  2016-04-06 21:20:44 +0000 UTC      -23.602608      -46.645084
# 552  1970-01-01 00:00:00 +0000 UTC      -23.601718      -46.646871
# 553  2015-12-18 00:01:01 +0000 UTC      -23.607114      -46.566483
#
#                       Dropoff Time  Dropoff Lat  Dropoff Lng  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City                  554 non-null    int64
#  1   Product Type          551 non-null    object
#  2   Trip or Order Status  554 non-null    object
#  3   Request Time          554 non-null    object
#  4   Begin Trip Time       554 non-null    object
#  5   Begin Trip Lat        525 non-null    float64
#  6   Begin Trip Lng        525 non-null    float64
#  7   Dropoff Time          554 non-null    object
#  8   Dropoff Lat           525 non-null    float64
#  9   Dropoff Lng           525 non-null    float64
#  10  Distance (miles)      554 non-null    float64
#  11  Fare Amount           554 non-null    float64
#  12  Fare Currency         551 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB

# %%
df.describe()
# Out:
#              City  Begin Trip Lat  Begin Trip Lng  Dropoff Lat  Dropoff Lng  \
# count   554.00000      525.000000      525.000000   525.000000   525.000000
# mean    473.51444      -23.560695      -46.622412   -23.567343   -46.615599
# std     125.84521        0.069152        0.240816     0.070309     0.241447
# min     296.00000      -23.975843      -46.837136   -23.975838   -46.837120
# 25%     458.00000      -23.602633      -46.666376   -23.611162   -46.666338
# 50%     458.00000      -23.559450      -46.644786   -23.568158   -46.637291
# 75%     458.00000      -23.503640      -46.624974   -23.507593   -46.623503
# max    1449.00000      -22.903051      -43.105089   -22.902098   -43.114359
#
#        Distance (miles)  Fare Amount
# count        554.000000   554.000000
# mean           4.047473    16.280361
# std            3.752974    12.445731
# min            0.000000     0.000000
# 25%            1.180000     7.872500
# 50%            3.275000    15.100000
# ...

# %%
df.isnull().sum()
# Out:
# City                     0
# Product Type             3
# Trip or Order Status     0
# Request Time             0
# Begin Trip Time          0
# Begin Trip Lat          29
# Begin Trip Lng          29
# Dropoff Time             0
# Dropoff Lat             29
# Dropoff Lng             29
# Distance (miles)         0
# Fare Amount              0
# Fare Currency            3
# dtype: int64

# %%
df.describe()
# Out:
#              City  Begin Trip Lat  Begin Trip Lng  Dropoff Lat  Dropoff Lng  \
# count   554.00000      525.000000      525.000000   525.000000   525.000000
# mean    473.51444      -23.560695      -46.622412   -23.567343   -46.615599
# std     125.84521        0.069152        0.240816     0.070309     0.241447
# min     296.00000      -23.975843      -46.837136   -23.975838   -46.837120
# 25%     458.00000      -23.602633      -46.666376   -23.611162   -46.666338
# 50%     458.00000      -23.559450      -46.644786   -23.568158   -46.637291
# 75%     458.00000      -23.503640      -46.624974   -23.507593   -46.623503
# max    1449.00000      -22.903051      -43.105089   -22.902098   -43.114359
#
#        Distance (miles)  Fare Amount
# count        554.000000   554.000000
# mean           4.047473    16.280361
# std            3.752974    12.445731
# min            0.000000     0.000000
# 25%            1.180000     7.872500
# 50%            3.275000    15.100000
# ...

# %%
df.corr()
# Out:
#                       City  Begin Trip Lat  Begin Trip Lng  Dropoff Lat  \
# City              1.000000       -0.434776        0.231321    -0.414049
# Begin Trip Lat   -0.434776        1.000000        0.499368     0.823337
# Begin Trip Lng    0.231321        0.499368        1.000000     0.512152
# Dropoff Lat      -0.414049        0.823337        0.512152     1.000000
# Dropoff Lng       0.229784        0.479293        0.984777     0.481896
# Distance (miles) -0.086285       -0.047790       -0.033502    -0.138765
# Fare Amount      -0.088148       -0.084002       -0.045281    -0.142783
#
#                   Dropoff Lng  Distance (miles)  Fare Amount
# City                 0.229784         -0.086285    -0.088148
# Begin Trip Lat       0.479293         -0.047790    -0.084002
# Begin Trip Lng       0.984777         -0.033502    -0.045281
# Dropoff Lat          0.481896         -0.138765    -0.142783
# Dropoff Lng          1.000000          0.005534    -0.010650
# ...

# %%
df.columns
# Out:
# Index(['City', 'Product Type', 'Trip or Order Status', 'Request Time',
#        'Begin Trip Time', 'Begin Trip Lat', 'Begin Trip Lng', 'Dropoff Time',
#        'Dropoff Lat', 'Dropoff Lng', 'Distance (miles)', 'Fare Amount',
#        'Fare Currency'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#       City  Product Type  Trip or Order Status  Request Time  Begin Trip Time  \
# 0    False         False                 False         False            False
# 1    False         False                 False         False            False
# 2    False         False                 False         False            False
# 3    False         False                 False         False            False
# 4    False         False                 False         False            False
# ..     ...           ...                   ...           ...              ...
# 549  False         False                 False         False            False
# 550  False         False                 False         False            False
# 551  False         False                 False         False            False
# 552  False         False                 False         False            False
# 553  False         False                 False         False            False
#
# ...

# %%
df.isnull().sum()
# Out:
# City                     0
# Product Type             3
# Trip or Order Status     0
# Request Time             0
# Begin Trip Time          0
# Begin Trip Lat          29
# Begin Trip Lng          29
# Dropoff Time             0
# Dropoff Lat             29
# Dropoff Lng             29
# Distance (miles)         0
# Fare Amount              0
# Fare Currency            3
# dtype: int64

# %%
df.notnull().sum()
# Out:
# City                    554
# Product Type            551
# Trip or Order Status    554
# Request Time            554
# Begin Trip Time         554
# Begin Trip Lat          525
# Begin Trip Lng          525
# Dropoff Time            554
# Dropoff Lat             525
# Dropoff Lng             525
# Distance (miles)        554
# Fare Amount             554
# Fare Currency           551
# dtype: int64

# %%
x=df.isnull().sum().sum()

# %%
y=df.notnull().sum().sum()

# %%
x
# Out:
# 122

# %%
y
# Out:
# 7080

# %%
y-x
# Out:
# 6958

# %%
df.shape
# Out:
# (554, 13)

# %%
df.notnull().sum()
# Out:
# City                    554
# Product Type            551
# Trip or Order Status    554
# Request Time            554
# Begin Trip Time         554
# Begin Trip Lat          525
# Begin Trip Lng          525
# Dropoff Time            554
# Dropoff Lat             525
# Dropoff Lng             525
# Distance (miles)        554
# Fare Amount             554
# Fare Currency           551
# dtype: int64
